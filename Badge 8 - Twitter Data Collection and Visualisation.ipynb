# %% [markdown]
# In this notebook:
#
# 1. [Connecting to the Twitter API](#1)
# 2. [Searching for a specific user](#2)
# 3. [Searching for a specific topic](#3)
# 4. [Extending the search and working with multi-level JSON Data](#4)

# %% [markdown]
# <a id="1"></a>
# # 1. Connecting to the Twitter API
#
# ## Questions & Objectives
#
# * Setting up access and validity signing
# * Setting up a handler to manage the connection
# * Running a test search

# %% [markdown]
# First we will download the libraries that deal with accessing the API (`tweepy`) and working with the JSON data (`json`).

# %%
# Run this cell now to import the libraries.

# !pip install tweepy
import tweepy        # https://github.com/tweepy/tweepy
import json
# Out:
# Collecting tweepy
#   Downloading tweepy-4.1.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 340 kB/s eta 0:00:011
# Requirement already satisfied: requests<3,>=2.11.1 in /opt/conda/lib/python3.9/site-packages (from tweepy) (2.25.1)
# Collecting requests-oauthlib<2,>=1.0.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.11.1->tweepy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.11.1->tweepy) (1.26.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from requests-oauthlib<2,>=1.0.0->tweepy) (3.0.1)
# Installing collected packages: requests-oauthlib, tweepy
# Successfully installed requests-oauthlib-1.3.0 tweepy-4.1.0

# %% [markdown]
# We then set up the variables that hold the validation keys. You need to add your keys (tokens) and secrets in the spaces below. Make sure to put them between the speech marks and make sure there are no extra spaces.

# %%
# Add your keys and secrets and then run this cell.

access_key = '1444594707762491400-nQyEz2VHb86agzZ9EprDEziaqiDlVB'
access_secret = 'yPJLLNRkCXuEgxf0cJjKzO9zhDnGUPDP3yq1bcdW2a6Bq'
api_key = 'rMIe3li9R8JSp8BErscVgcvlM'
api_secret = 'wNz795MCrls3kreC8zY1nAer9db3FHAol7jWaqFKxQZf610nI4'

# %% [markdown]
# Next, we set up the authication handler. We pass the keys and secrets as below and then set up the API object. We can use this object to connect to the API.

# %%
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %% [markdown]
# To test the connection we will run a test query.
#
# We use the API object and we are going to ask for some of the tweets from users you follow.

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Fergus, as relentless as ever in his desire to help me prep for teaching https://t.co/BMAEMUIMc6
# In advance of the new academic year I have decided to finally close all the open tabs. If I haven't been read/watch… https://t.co/C0PGC7bzsX
# Trying times for Noodle.  Lacking cat skills she will never catch that bird. https://t.co/27pxdkZt8V
# some sun on the bum https://t.co/GLD0wCV2vJ
# RT @cesifoti: The academic circle of life 😂 https://t.co/9hm6EtNS03
# RT @articonf: ARTICONF impressed the reviewers with their advancements in the 2nd year and passed the EC review yesterday.
#
# The project of…
# RT @chazhutton: Today’s Comic: We are all, in our own little way, that ship. https://t.co/GVDjLxzErX
# Spring is here! Another amazing winter of freezing sweary swims in the bag. https://t.co/YI8p1splVh
# RT @MemeStudiesRN: Do you have a hot take about memes? A bone to pick with Elon Musk? A subgenre of memes that you think the world needs to…
# RT @EdCDCS: Kicking off our workshop presented by @BostonJoan from @ShorensteinCtr on media manipulation and #disinformation - topical cont…
# RT @brian_bilston: I’m beginning to have doubts that this month is ever going to end. https://t.co/qBZn71IIha
# RT @idilgalip: Where do we start when writing about memes? Dawkins? Shifman? Aristotle? You can read my thoughts on the matter in our first…
# A bracing and quite sweary Christmas eve swim. Joyful! https://t.co/iaNvxIlmih
# Yup. https://t.co/xymC0cC7QP
# Never have I been happier to put the out of office on. Jingle bells everyone. And breathe. https://t.co/ykpABsQqUr
# RT @pedro_jac: Are you interested in #blockchain technologies? @katyoj and I are looking for people who'd like to share ideas, hopes and co…
# Huge congratulations @mscdigsoc MSc graduates on your virtual graduation day. As fitting as the virtual is for a di… https://t.co/72CIN4ic9h
# RT @idilgalip: Dear Edinburgh Uni friends, please consider signing this petition to stop face-to-face teaching and non-essential in-person…
# RT @BSADigitalSoc: Event registration: sex and social media, a conversation with Dr Katrin Tiidenberg and Dr Emily van der Nagel. Thursday…
# Join the BSA DIgital Sociology study group on 3rd  December 9.00–10.00 GMT when Katrin Tiidenberg &amp; Emily van der N… https://t.co/mTpgFgtdfP

# %% [markdown]
# <a id="2"></a>
# # 2. Searching for a Specific User
#
# * Search for a specific user
# * Retrieve data from the Twitter API
# * Call specific items from the JSON data object
# * Look at the full JSON data
#
# We will now look for tweets from a specific person. To do this we need their Twitter name. If you go to https://twitter.com/BarackObama you can see the Twitter name under the main name. You can see it has an @ sign in front that we remove from our code.
#
# For this we use the `get_user` method from the Twitter API.

# %%
# First, we create a variable, call the information on the user Barack Obama, and hold it
# in the variable we created.

user = api.get_user(screen_name='BarackObama')

# %%
# This object is in JSON tuples.
# We can call the tuples and print their content. 
# We will look more at JSON later.
# We can print the screen name as below:

print(user.screen_name)
# Out:
# BarackObama

# %%
# We can print the number of followers:

print(user.followers_count)
# Out:
# 130096417

# %%
# We can print the user description:

print(user.description)
# Out:
# Dad, husband, President, citizen.

# %%
# To see all of the user information in its raw format we can type:

print(user)
# Out:
# User(_api=<tweepy.api.API object at 0x7f69d0299520>, _json={'id': 813286, 'id_str': '813286', 'name': 'Barack Obama', 'screen_name': 'BarackObama', 'location': 'Washington, DC', 'profile_location': None, 'description': 'Dad, husband, President, citizen.', 'url': 'https://t.co/FPuJ0CENpo', 'entities': {'url': {'urls': [{'url': 'https://t.co/FPuJ0CENpo', 'expanded_url': 'http://obamabook.com', 'display_url': 'obamabook.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 130096417, 'friends_count': 588790, 'listed_count': 222607, 'created_at': 'Mon Mar 05 22:08:25 +0000 2007', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 16279, 'lang': None, 'status': {'created_at': 'Sun Oct 10 00:48:08 +0000 2021', 'id': 1447000963672428545, 'id_str': '1447000963672428545', 'text': 'I was deeply saddened to learn about the passing of General Ray Odierno after a battle with cancer. He devoted his… https://t.co/m2Lr2GZaOb', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/m2Lr2GZaOb', 'expanded_url': 'https://twitter.com/i/web/status/1447000963672428545', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2514, 'favorite_count': 28692, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '77B0DC', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1329647526807543809/2SGvnHYV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1329647526807543809/2SGvnHYV_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/813286/1633800288', 'profile_link_color': '2574AD', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'C2E0F6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, id=813286, id_str='813286', name='Barack Obama', screen_name='BarackObama', location='Washington, DC', profile_location=None, description='Dad, husband, President, citizen.', url='https://t.co/FPuJ0CENpo', entities={'url': {'urls': [{'url': 'https://t.co/FPuJ0CENpo', 'expanded_url': 'http://obamabook.com', 'display_url': 'obamabook.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=130096417, friends_count=588790, listed_count=222607, created_at=datetime.datetime(2007, 3, 5, 22, 8, 25, tzinfo=datetime.timezone.utc), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=True, statuses_count=16279, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f69d0299520>, _json={'created_at': 'Sun Oct 10 00:48:08 +0000 2021', 'id': 1447000963672428545, 'id_str': '1447000963672428545', 'text': 'I was deeply saddened to learn about the passing of General Ray Odierno after a battle with cancer. He devoted his… https://t.co/m2Lr2GZaOb', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/m2Lr2GZaOb', 'expanded_url': 'https://twitter.com/i/web/statu ...

# %% [markdown]
# ### 🐛Minitask
#
# * Try using the information from the user to print out to access the other information.
# * See if you can work out how to get to the nested tuples.
# * Try and look at another user.

# %%
# We can get tweets from the API user timeline.
# This time we call the user_timeline method again with the BarackObama user method.
# Here we call the last two tweets.
# These are retured in a list object.

new_tweets = api.user_timeline(screen_name = 'BarackObama', count = 2)   # replace BarackObama with another user's name

# %%
# Here we can tweet the first tweet (which remember is 0 in a list).
# What other information can you access from the tweets?  How about the number of retweets?

new_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x7f69d0299520>, _json={'created_at': 'Sun Oct 10 00:48:08 +0000 2021', 'id': 1447000963672428545, 'id_str': '1447000963672428545', 'text': 'I was deeply saddened to learn about the passing of General Ray Odierno after a battle with cancer. He devoted his… https://t.co/m2Lr2GZaOb', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/m2Lr2GZaOb', 'expanded_url': 'https://twitter.com/i/web/status/1447000963672428545', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 813286, 'id_str': '813286', 'name': 'Barack Obama', 'screen_name': 'BarackObama', 'location': 'Washington, DC', 'description': 'Dad, husband, President, citizen.', 'url': 'https://t.co/FPuJ0CENpo', 'entities': {'url': {'urls': [{'url': 'https://t.co/FPuJ0CENpo', 'expanded_url': 'http://obamabook.com', 'display_url': 'obamabook.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 130096539, 'friends_count': 588790, 'listed_count': 222607, 'created_at': 'Mon Mar 05 22:08:25 +0000 2007', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 16279, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '77B0DC', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1329647526807543809/2SGvnHYV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1329647526807543809/2SGvnHYV_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/813286/1633800288', 'profile_link_color': '2574AD', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'C2E0F6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2514, 'favorite_count': 28697, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 10, 0, 48, 8, tzinfo=datetime.timezone.utc), id=1447000963672428545, id_str='1447000963672428545', text='I was deeply saddened to learn about the passing of General Ray Odierno after a battle with cancer. He devoted his… https://t.co/m2Lr2GZaOb', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/m2Lr2GZaOb', 'expanded_url': 'https://twitter.com/i/web/status/1447000963672428545', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f69d0299520>, _json={'id': 813286, 'id_str': '813286', 'name': 'Barack Obama', 'screen_name': 'BarackObama', 'location': 'Washington, DC', 'description': 'Dad, husband, President, citizen.', 'url': 'https://t.co/FPuJ0CENpo', 'entities': {'url': {'urls': [{'url': 'https://t.co/FPuJ0CENpo', 'expanded_url': 'http://obamabook.com', 'display_url': 'obamabook.com', 'indices': [0, 23]}]}, 'description': {' ...

# %% [markdown]
# <a id="3"></a>
# # 3. Searching for a Topic
#
# * Search the Twitter API using a keyword
# * Retrieve the text from a single tweet
# * Retrieve the text from multiple tweets
# * Process and clean the text
# * Visualise the text
#
# We will now look for tweets that contain a specific word.
#
# For this we use the `search` method from the Twitter API.

# %%
# Here we are looking for the word covid.
# We are asking for 10 english tweets to be returned.
# They are returned as a list.

covid_tweets = api.search_tweets(q='covid', lang='en', count='10')

# %%
# We can print out the first tweet in the list.

covid_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x7f69d0299520>, _json={'created_at': 'Tue Oct 12 13:19:52 +0000 2021', 'id': 1447914918234238984, 'id_str': '1447914918234238984', 'text': 'RT @DonaldJTrumpJr: The fact that thousands of Southwest employees walked off the job protesting the COVID vaccine mandate forcing the airl…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DonaldJTrumpJr', 'name': 'Donald Trump Jr.', 'id': 39344374, 'id_str': '39344374', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1350506743743311872, 'id_str': '1350506743743311872', 'name': 'Laura', 'screen_name': 'Laura22320905', 'location': '', 'description': "Christian Women \nConservative God Loving\nFamily & Country Loving  MAGA!!  NO DM's \nStop Murdering The Unborn Human!", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 373, 'friends_count': 521, 'listed_count': 0, 'created_at': 'Sat Jan 16 18:14:50 +0000 2021', 'favourites_count': 21309, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8287, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1405595228631879689/OawVB-fh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1405595228631879689/OawVB-fh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1350506743743311872/1614561918', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Oct 11 22:12:52 +0000 2021', 'id': 1447686667071115264, 'id_str': '1447686667071115264', 'text': 'The fact that thousands of Southwest employees walked off the job protesting the COVID vaccine mandate forcing the… https://t.co/q32moIqnQ8', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/q32moIqnQ8', 'expanded_url': 'https://twitter.com/i/web/status/1447686667071115264', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 39344374, 'id_str': '39344374', 'name': 'Donald Trump Jr.', 'screen_name': 'DonaldJTrumpJr', 'location': '', 'description': 'EVP of Development & Acquisitions The @Trump Organization, Father, Outdoorsman, In a past life Boardroom Advisor on The Apprentice, Pronouns: Your Hero', 'url': 'https://t.co/7kZtMLWKic', 'entities': {'url': {'urls': [{'url': 'https://t.co/7kZtMLWKic', 'expanded_url': 'https://donjr.com/', 'display_url': 'donjr.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 7069808, 'friends_count': 1561, 'listed_count': 16925, 'created_at': 'Mon May 11 21:18:33 ...

# %% [markdown]
# This time we can't just call the JSON from the object (like we did with the user object).
# We have to deal with the JSON directly. We do this using the `_json` function.
# Then we can call all of the tuples as a dictionary object.
#
# (Remember a tuple takes the form `['text':'this is tweet text']`, which means that we can retrieve the content of the tuple by the key of the tuple.)

# %%
# Here we can see all of the json in a nice format...

covid_tweets[0]._json
# Out:
# {'created_at': 'Tue Oct 12 13:19:52 +0000 2021',
#  'id': 1447914918234238984,
#  'id_str': '1447914918234238984',
#  'text': 'RT @DonaldJTrumpJr: The fact that thousands of Southwest employees walked off the job protesting the COVID vaccine mandate forcing the airl…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'DonaldJTrumpJr',
#     'name': 'Donald Trump Jr.',
#     'id': 39344374,
#     'id_str': '39344374',
#     'indices': [3, 18]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1350506743743311872,
#   'id_str': '1350506743743311872',
#   'name': 'Laura',
#   'screen_name': 'Laura22320905',
#   'location': '',
#   'description': "Christian Women \nConservative God Loving\nFamily & Country Loving  MAGA!!  NO DM's \nStop Murdering The Unborn Human!",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 373,
#   'friends_count': 521,
#   'listed_count': 0,
#   'created_at': 'Sat Jan 16 18:14:50 +0000 2021',
#   'favourites_count': 21309,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 8287,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1405595228631879689/OawVB-fh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1405595228631879689/OawVB-fh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1350506743743311872/1614561918',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Mon Oct 11 22:12:52 +0000 2021',
#   'id': 1447686667071115264,
#   'id_str': '1447686667071115264',
#   'text': 'The fact that thousands of Southwest employees walked off the job protesting the COVID vaccine mandate forcing the… https://t.co/q32moIqnQ8',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/q32moIqnQ8',
#      'expanded_url': 'https://twitter.com/i/web/status/1447686667071115264',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 39344374,
#    'id_str': '39344374',
#    'name': 'Donald Trump Jr.',
#    'screen_name': 'DonaldJTrumpJr',
#    'location': '',
#    'description': 'EVP of Development & Acquisitions The @Trump Organization, Father, Outdoorsman, In a past life Boardroom Advisor on The Apprentice, Pronouns: Your Hero',
#    'url': 'https://t.co/7kZtMLWKic',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/7kZtMLWKic',
#        'expanded_url': 'https://donjr.com/',
#        'display_url': 'donjr.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7069808,
#    'friends_count': 1561,
#    'listed_count': 16925,
#    'created_at': 'Mon May 11 21:18:33 +0000 2009',
#    'favourites_count': 24154,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 43670,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/766652495858896897/LjrJJB9a_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/766652495858896897/LjrJJB9a_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39344374/1630377810',
#    'profile_link_color': '15317E',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 13179,
#   'favorite_count': 51068,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 13179,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
# ...or we can just call the text.

covid_tweets[0]._json['text']
# Out:
# 'RT @DonaldJTrumpJr: The fact that thousands of Southwest employees walked off the job protesting the COVID vaccine mandate forcing the airl…'

# %%
# We can text put the text into its own list and just work with just the text.

tweets_text = []
for each in covid_tweets:
    tweets_text.append(each._json['text'])

# %%
# We can see how we have put the tweets' text into a list.

print(tweets_text)
# Out:
# ['RT @DonaldJTrumpJr: The fact that thousands of Southwest employees walked off the job protesting the COVID vaccine mandate forcing the airl…', 'RT @JoWilliams52: Hey @RoyalMail @parcelforce do you want to have a word with your drivers about a little thing called Covid-19? Just had a…', 'RT @aaronhoyland: Refusing to get your shot because vaccinated people can still catch Covid is a lot like refusing to wear your seatbelt be…', 'RT @naledimashishi: People don’t want to get tested for Covid, don’t want to get vaccinated, don’t want to wear masks, don’t want to social…', 'RT @AgnesSolberg: "Big Pharma" makes a LOT more money from the meds you get during your ICU admission then a cheap #covid vaccine.', '@680NEWS @Jette680News @Cook680News The COVID vaccines were prepared by the CCP in a very deliberate manner long ag… https://t.co/ucMHpQg33j', 'RT @thedailybeast: The British government’s dithering in the crucial early weeks of the coronavirus pandemic ended up costing thousands of…', 'RT @RWMaloneMD: "Taiwan death from COVID-19 vaccination exceeds death from COVID-19" \nVac deaths in Taiwan: 852 \nDeaths with COVID-19:  844…', "RT @mog7546: Doctor: 225 unvaccinated at #Yale New Haven Health told they'll lose their jobs Oct. 18\n\nIf they get vaccinated for COVID-19 b…", 'RT @HolmdelPatch: Eligible residents can get an extra dose of the COVID-19 vaccine at one of these locations. https://t.co/NrFTNguY0r']

# %%
# We can treat the tweets' text like we did in earlier badges,
# for example, we can turn it into a string and tokenise it.

tweets_string = " ".join(tweets_text)
from nltk.tokenize import word_tokenize
tokens = word_tokenize(tweets_string)
print(tokens[0:10])
# Out:
# ['RT', '@', 'DonaldJTrumpJr', ':', 'The', 'fact', 'that', 'thousands', 'of', 'Southwest']

# %%
# We can clean up the tweets' text like we did earlier, making it all lowercase and removing stop words.

import nltk
import string
nltk.download('stopwords')
from nltk.corpus import stopwords
lowercase_tokens = [token.lower() for token in tokens]
remove_these = set(stopwords.words('english') + list(string.punctuation) + list(string.digits))
filtered_text = [token 
                 for token in lowercase_tokens 
                 if not token in remove_these]
print(filtered_text)
# Out:
# ['rt', 'donaldjtrumpjr', 'fact', 'thousands', 'southwest', 'employees', 'walked', 'job', 'protesting', 'covid', 'vaccine', 'mandate', 'forcing', 'airl…', 'rt', 'jowilliams52', 'hey', 'royalmail', 'parcelforce', 'want', 'word', 'drivers', 'little', 'thing', 'called', 'covid-19', 'a…', 'rt', 'aaronhoyland', 'refusing', 'get', 'shot', 'vaccinated', 'people', 'still', 'catch', 'covid', 'lot', 'like', 'refusing', 'wear', 'seatbelt', 'be…', 'rt', 'naledimashishi', 'people', '’', 'want', 'get', 'tested', 'covid', '’', 'want', 'get', 'vaccinated', '’', 'want', 'wear', 'masks', '’', 'want', 'social…', 'rt', 'agnessolberg', '``', 'big', 'pharma', "''", 'makes', 'lot', 'money', 'meds', 'get', 'icu', 'admission', 'cheap', 'covid', 'vaccine', '680news', 'jette680news', 'cook680news', 'covid', 'vaccines', 'prepared', 'ccp', 'deliberate', 'manner', 'long', 'ag…', 'https', '//t.co/ucmhpqg33j', 'rt', 'thedailybeast', 'british', 'government', '’', 'dithering', 'crucial', 'early', 'weeks', 'coronavirus', 'pandemic', 'ended', 'costing', 'thousands', 'of…', 'rt', 'rwmalonemd', '``', 'taiwan', 'death', 'covid-19', 'vaccination', 'exceeds', 'death', 'covid-19', "''", 'vac', 'deaths', 'taiwan', '852', 'deaths', 'covid-19', '844…', 'rt', 'mog7546', 'doctor', '225', 'unvaccinated', 'yale', 'new', 'health', 'told', "'ll", 'lose', 'jobs', 'oct.', '18', 'get', 'vaccinated', 'covid-19', 'b…', 'rt', 'holmdelpatch', 'eligible', 'residents', 'get', 'extra', 'dose', 'covid-19', 'vaccine', 'one', 'locations', 'https', '//t.co/nrftnguy0r']
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# We can calculate word frequencies...

from collections import Counter
simple_frequencies_dict = Counter(filtered_text)
# Out:
# Counter({'rt': 9, 'covid-19': 6, 'get': 6, 'covid': 5, 'want': 5, '’': 5, 'vaccine': 3, 'vaccinated': 3, 'thousands': 2, 'refusing': 2, 'people': 2, 'lot': 2, 'wear': 2, '``': 2, "''": 2, 'https': 2, 'taiwan': 2, 'death': 2, 'deaths': 2, 'donaldjtrumpjr': 1, 'fact': 1, 'southwest': 1, 'employees': 1, 'walked': 1, 'job': 1, 'protesting': 1, 'mandate': 1, 'forcing': 1, 'airl…': 1, 'jowilliams52': 1, 'hey': 1, 'royalmail': 1, 'parcelforce': 1, 'word': 1, 'drivers': 1, 'little': 1, 'thing': 1, 'called': 1, 'a…': 1, 'aaronhoyland': 1, 'shot': 1, 'still': 1, 'catch': 1, 'like': 1, 'seatbelt': 1, 'be…': 1, 'naledimashishi': 1, 'tested': 1, 'masks': 1, 'social…': 1, 'agnessolberg': 1, 'big': 1, 'pharma': 1, 'makes': 1, 'money': 1, 'meds': 1, 'icu': 1, 'admission': 1, 'cheap': 1, '680news': 1, 'jette680news': 1, 'cook680news': 1, 'vaccines': 1, 'prepared': 1, 'ccp': 1, 'deliberate': 1, 'manner': 1, 'long': 1, 'ag…': 1, '//t.co/ucmhpqg33j': 1, 'thedailybeast': 1, 'british': 1, 'government': 1, 'dithering': 1, 'crucial': 1, 'early': 1, 'weeks': 1, 'coronavirus': 1, 'pandemic': 1, 'ended': 1, 'costing': 1, 'of…': 1, 'rwmalonemd': 1, 'vaccination': 1, 'exceeds': 1, 'vac': 1, '852': 1, '844…': 1, 'mog7546': 1, 'doctor': 1, '225': 1, 'unvaccinated': 1, 'yale': 1, 'new': 1, 'health': 1, 'told': 1, "'ll": 1, 'lose': 1, 'jobs': 1, 'oct.': 1, '18': 1, 'b…': 1, 'holmdelpatch': 1, 'eligible': 1, 'residents': 1, 'extra': 1, 'dose': 1, 'one': 1, 'locations': 1, '//t.co/nrftnguy0r': 1})

# %%
# ...and produce word clouds.

import matplotlib.pyplot as plt
from wordcloud import WordCloud

cloud = WordCloud(width=800, 
                  height=400, 
                  max_font_size=160, 
                  colormap="hsv").generate_from_frequencies(simple_frequencies_dict)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🐛Minitask
#
# * Try using a visualisation method or a search method you have used before to visualise the text.
# * Try searching for a different word.

# %%
# Write your code here.

# %% [markdown]
# <a id="4"></a>
# ## 4. Extending the search and working with multi-level JSON Data
#
# * Search the Twitter API using an extended query with multiple terms
# * Search using a tweepy cursor to retrieve more data
# * Look at nested data in the JSON
#
# We will now look for tweets that contain several words. We can combine query words with the operator `OR`. We can use this operator to say, give me tweets that contain `word1` or `word2`. You might want to do this with related words on the same topic, or with multiple spellings or potential typos of a word.
#
# For this we will continue to use the `search` method from the Twitter API.
#
# We want to gather more data than we did before. The `search` method limits the data we can retrieve. To extend the amount of data we retrieve we use a tweepy `Cursor`. Twitter returns multiple pages of data, almost like a book, but it will only give you one page at a time. Before, we only took the first page. This time, we will page through the extended version using a `Cursor` object. The `Cursor` maintains the connection with the API and allows us to ask for the next page.

# %%
# We set up a list to hold the tweets so we can then append to it as we iterate through the pages.
# Previously, we created a list in the search, but here we need to create a list so we can add to it.

covid_tweets = []

# We set up a tweepy Cursor to maintain the connection.
# We set up the query with the OR operator.
# We iterate through the pages from the API using a for loop.
# We append the content to a list.
for page in tweepy.Cursor(api.search_tweets, 
                          q='covid OR covid19 OR COVID OR COVID19 or #covid', 
                          lang='en').pages(10):
    covid_tweets.append(page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3912380399c9> in <module>
#       8 # We iterate through the pages from the API using a for loop.
#       9 # We append the content to a list.
# ---> 10 for page in tweepy.Cursor(api.search_tweets,
#      11                           q='covid OR covid19 OR COVID OR COVID19 or #covid',
#      12                           lang='en').pages(10):
#
# NameError: name 'tweepy' is not defined

# %%
covid_tweets[0]
# Out:
# [Status(_api=None, _json={'created_at': 'Tue Oct 12 13:51:53 +0000 2021', 'id': 1447922978495385600, 'id_str': '1447922978495385600', 'text': 'RT @wqbelle: To mask, or not to mask, that should not be a question.\n\nhttps://t.co/Sa4xEjK9wp\n\nI have to shake my head at all the protests…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'wqbelle', 'name': 'William Quincy Belle', 'id': 157050864, 'id_str': '157050864', 'indices': [3, 11]}], 'urls': [{'url': 'https://t.co/Sa4xEjK9wp', 'expanded_url': 'https://www.williamquincybelle.com/2021/09/masks-how-we-hate-change.html', 'display_url': 'williamquincybelle.com/2021/09/masks-…', 'indices': [70, 93]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 157050864, 'id_str': '157050864', 'name': 'William Quincy Belle', 'screen_name': 'wqbelle', 'location': '', 'description': 'just on a whim\n\nAmazon https://t.co/aoYR4Sf7eF', 'url': 'https://t.co/Rr75b5Vfqp', 'entities': {'url': {'urls': [{'url': 'https://t.co/Rr75b5Vfqp', 'expanded_url': 'https://www.WilliamQuincyBelle.com', 'display_url': 'WilliamQuincyBelle.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/aoYR4Sf7eF', 'expanded_url': 'https://www.amazon.com/William-Quincy-Belle/e/B01M1IQ69G', 'display_url': 'amazon.com/William-Quincy…', 'indices': [23, 46]}]}}, 'protected': False, 'followers_count': 615, 'friends_count': 18, 'listed_count': 121, 'created_at': 'Fri Jun 18 18:15:33 +0000 2010', 'favourites_count': 1272, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 15554, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1060031794735542272/kY-qRgxc_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1060031794735542272/kY-qRgxc_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/157050864/1573607606', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 05 04:15:56 +0000 2021', 'id': 1445241319656509442, 'id_str': '1445241319656509442', 'text': 'To mask, or not to mask, that should not be a question.\n\nhttps://t.co/Sa4xEjK9wp\n\nI have to shake my head at all th… https://t.co/xiPgpdHMGy', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Sa4xEjK9wp', 'expanded_url': 'https://www.williamquincybelle.com/2021/09/masks-how-we-hate-change.html', 'display_url': 'williamquincybelle.com/2021/09/masks-…', 'indices': [57, 80]}, {'url': 'https://t.co/xiPgpdHMGy', 'expanded_url': 'https://twitter.com/i/web/status/1445241319656509442', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_rep ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:49:07 +0000 2021', 'id': 1447922280542228486, 'id_str': '1447922280542228486', 'text': 'RT @TheLCPR: Here is a full fact sheet of issues, published by a real virologist/MD which supervisors can use to push back on being forced…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TheLCPR', 'name': 'London Center for Policy Research', 'id': 1329878034, 'id_str': '1329878034', 'indices': [3, 11]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1112471235512934404, 'id_str': '1112471235512934404', 'name': 'SURVIVOR', 'screen_name': 'SURVIVOR356', 'location': 'On solid ground...all else is sinking sand.', 'description': 'Survivor💙Jesuslovesme❤️Jarheadwife~0317Mom~USMC/AFR\nRN/Grandma❤️Jeremiah29:11📖\nRedpilledPatriot~GodBlessUSA🙏🏼\n        MAGA❤️🇺🇸❤️KAG', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 979, 'friends_count': 1150, 'listed_count': 0, 'created_at': 'Sun Mar 31 21:46:26 +0000 2019', 'favourites_count': 42610, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 42951, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1325891683293257728/JCtbaJ1k_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1325891683293257728/JCtbaJ1k_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1112471235512934404/1605191427', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 13:48:00 +0000 2021', 'id': 1447922000157102080, 'id_str': '1447922000157102080', 'text': 'Here is a full fact sheet of issues, published by a real virologist/MD which supervisors can use to push back on be… https://t.co/W5lvnhlkEi', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/W5lvnhlkEi', 'expanded_url': 'https://twitter.com/i/web/status/1447922000157102080', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://meetedgar.com" rel="nofollow">MeetEdgar</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1329878034, 'id_str': '1329878034', 'name': 'London Center for Policy Research', 'screen_name': 'TheLCPR', 'location': 'New York, USA', 'description': 'Challenging conventional wisdom, adding texture to the current deliberations on policy, & building support for positions that further the national interest.', 'url': 'https://t.co/seXbVsvZVj', 'entities': {'url': {'urls': [{'url': 'https://t.co/seXbVsvZVj', 'expanded_url': 'https://londoncenter.org', 'display_url': 'londoncenter.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2911, 'friends_count': 1089, 'listed_co ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:48:24 +0000 2021', 'id': 1447922101336350736, 'id_str': '1447922101336350736', 'text': 'RT @DrEricDing: Progress or no? \n\n📌1918–The Great Pandemic. With no vaccines—50 million died.\n \n📌1969–Humans land on the moon\n\n📌2020–COVID…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DrEricDing', 'name': 'Eric Feigl-Ding', 'id': 18831926, 'id_str': '18831926', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1164547427212247042, 'id_str': '1164547427212247042', 'name': 'Chins', 'screen_name': 'chinery_matt', 'location': 'western australia', 'description': '🚫NoDMs - 💉💉 - Spectrum - Commie from WestAussie - Self-deprecating/depreciating - The Quiet One - Introverted AF - Chaotic Neutral - Just Really Tired Man', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 421, 'friends_count': 1163, 'listed_count': 0, 'created_at': 'Thu Aug 22 14:39:08 +0000 2019', 'favourites_count': 48220, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 7688, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1442681851970162691/9AiB-_ds_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1442681851970162691/9AiB-_ds_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1164547427212247042/1616287200', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 07:20:15 +0000 2021', 'id': 1447824420983263236, 'id_str': '1447824420983263236', 'text': 'Progress or no? \n\n📌1918–The Great Pandemic. With no vaccines—50 million died.\n \n📌1969–Humans land on the moon\n\n📌202… https://t.co/LUJll9I4bz', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/LUJll9I4bz', 'expanded_url': 'https://twitter.com/i/web/status/1447824420983263236', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18831926, 'id_str': '18831926', 'name': 'Eric Feigl-Ding', 'screen_name': 'DrEricDing', 'location': 'Washington DC & Virginia', 'description': "Epidemiologist & health economist. Senior Fellow @FAScientists. Health policy @NECSI. Former 16 years @Harvard. @JohnsHopkins alum. COVID Updates since Jan '20", 'url': 'https://t.co/ipohSRjmIW', 'entities': {'url': {'urls': [{'url': 'https://t.co/ipohSRjmIW', 'expanded_url': 'http://fas.org/expert/eric-feigl-ding/', 'display_url': 'fas.org/expert/eric-fe…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 59516 ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:48:05 +0000 2021', 'id': 1447922022714052623, 'id_str': '1447922022714052623', 'text': 'RT @Bkasparas: @BBCNews @robertcuffe Worth remembering that anyone with even marginal cardiac or respiratory impairment post #COVID would a…', 'truncated': False, 'entities': {'hashtags': [{'text': 'COVID', 'indices': [125, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Bkasparas', 'name': 'Bernard Kasparas 💙', 'id': 269864868, 'id_str': '269864868', 'indices': [3, 13]}, {'screen_name': 'BBCNews', 'name': 'BBC News (UK)', 'id': 612473, 'id_str': '612473', 'indices': [15, 23]}, {'screen_name': 'robertcuffe', 'name': 'Robert Cuffe', 'id': 60854393, 'id_str': '60854393', 'indices': [24, 36]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1270666821776089090, 'id_str': '1270666821776089090', 'name': 'John', 'screen_name': 'John55139', 'location': '', 'description': "don't travel. emergency. report: N Ireland cases 252,208. victims brutally gone: 3,495 (potent, abnormal, origins?? COVID fatality rate 1 in 71). Long C: 26,000", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 100, 'friends_count': 72, 'listed_count': 0, 'created_at': 'Wed Jun 10 10:39:34 +0000 2020', 'favourites_count': 4841, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 15218, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1380179536617349130/LKeqLTkY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1380179536617349130/LKeqLTkY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1270666821776089090/1629961402', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 13:43:53 +0000 2021', 'id': 1447920964357050385, 'id_str': '1447920964357050385', 'text': '@BBCNews @robertcuffe Worth remembering that anyone with even marginal cardiac or respiratory impairment post… https://t.co/cvUB4Ojq1K', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BBCNews', 'name': 'BBC News (UK)', 'id': 612473, 'id_str': '612473', 'indices': [0, 8]}, {'screen_name': 'robertcuffe', 'name': 'Robert Cuffe', 'id': 60854393, 'id_str': '60854393', 'indices': [9, 21]}], 'urls': [{'url': 'https://t.co/cvUB4Ojq1K', 'expanded_url': 'https://twitter.com/i/web/status/1447920964357050385', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [111, 134]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1447919799149989889, 'in_reply_to_status_id_str': '1447919799149989889', 'in_reply_to_user_id': 269864868, 'in_reply_to_user_id_str': '269864868', 'in_reply_to_screen_name': 'Bkasparas', 'user': {'id': 269864868, 'id_str': '269864868', 'name': 'Bernard Kasparas 💙', 'screen_name': 'Bkasparas', 'location': 'Surr ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:48:00 +0000 2021', 'id': 1447922000157102080, 'id_str': '1447922000157102080', 'text': 'Here is a full fact sheet of issues, published by a real virologist/MD which supervisors can use to push back on be… https://t.co/W5lvnhlkEi', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/W5lvnhlkEi', 'expanded_url': 'https://twitter.com/i/web/status/1447922000157102080', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://meetedgar.com" rel="nofollow">MeetEdgar</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1329878034, 'id_str': '1329878034', 'name': 'London Center for Policy Research', 'screen_name': 'TheLCPR', 'location': 'New York, USA', 'description': 'Challenging conventional wisdom, adding texture to the current deliberations on policy, & building support for positions that further the national interest.', 'url': 'https://t.co/seXbVsvZVj', 'entities': {'url': {'urls': [{'url': 'https://t.co/seXbVsvZVj', 'expanded_url': 'https://londoncenter.org', 'display_url': 'londoncenter.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2911, 'friends_count': 1089, 'listed_count': 41, 'created_at': 'Fri Apr 05 19:10:27 +0000 2013', 'favourites_count': 1161, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 2607, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1214739405069520897/zUFpOx4q_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214739405069520897/zUFpOx4q_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1329878034/1577399203', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 12, 13, 48, tzinfo=datetime.timezone.utc), id=1447922000157102080, id_str='1447922000157102080', text='Here is a full fact sheet of issues, published by a real virologist/MD which supervisors can use to push back on be… https://t.co/W5lvnhlkEi', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/W5lvnhlkEi', 'expanded_url': 'https://twitter.com/i/web/status/1447922000157102080', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='MeetEdgar', source_url='http://meetedgar.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=None, _json={'id': 1329878034, 'id_str': '1329878034', 'name': 'London Center for Policy Research', 'screen_name': 'TheLCPR', 'location': 'New York, USA', 'description': 'Challenging conventional wisdom, adding texture to  ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:47:29 +0000 2021', 'id': 1447921869869494285, 'id_str': '1447921869869494285', 'text': 'RT @StefSimanowitz: 1/. #BREAKING #COVID NEWSFLASH: The “official scientific advisers" behind the #HerdImmunityScandal were in reality were…', 'truncated': False, 'entities': {'hashtags': [{'text': 'BREAKING', 'indices': [24, 33]}, {'text': 'COVID', 'indices': [34, 40]}, {'text': 'HerdImmunityScandal', 'indices': [98, 118]}], 'symbols': [], 'user_mentions': [{'screen_name': 'StefSimanowitz', 'name': 'Stefan Simanowitz', 'id': 115393565, 'id_str': '115393565', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 171920075, 'id_str': '171920075', 'name': 'Heather H', 'screen_name': 'Dealoftheday123', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 636, 'friends_count': 2096, 'listed_count': 2, 'created_at': 'Wed Jul 28 13:58:24 +0000 2010', 'favourites_count': 44871, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 84901, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 06:52:02 +0000 2021', 'id': 1447817316335595520, 'id_str': '1447817316335595520', 'text': '1/. #BREAKING #COVID NEWSFLASH: The “official scientific advisers" behind the #HerdImmunityScandal were in reality… https://t.co/E4oWM2IG8I', 'truncated': True, 'entities': {'hashtags': [{'text': 'BREAKING', 'indices': [4, 13]}, {'text': 'COVID', 'indices': [14, 20]}, {'text': 'HerdImmunityScandal', 'indices': [78, 98]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/E4oWM2IG8I', 'expanded_url': 'https://twitter.com/i/web/status/1447817316335595520', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 115393565, 'id_str': '115393565', 'name': 'Stefan Simanowitz', 'screen_name': 'StefSimanowitz', 'location': 'stefan.simanowitz@amnesty.org', 'description': 'Campaigner || Investigative journalist || Activist II @Amnesty Media manager || All views are my own || Easily distracte', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 56464, 'friends_count': 10332, 'listed_count': 719, 'created_at': 'Thu Feb 18 14:29:43 +0000 2010', 'favourites_count': 28255, 'utc_offset': None, 'time_ ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:47:18 +0000 2021', 'id': 1447921822515793933, 'id_str': '1447921822515793933', 'text': '@StefMayoPghOhio @dr_cmm So sorry to hear #Covid hits people differently. Long term Covid problems are devastating… https://t.co/G0Tk55oI3k', 'truncated': True, 'entities': {'hashtags': [{'text': 'Covid', 'indices': [42, 48]}], 'symbols': [], 'user_mentions': [{'screen_name': 'StefMayoPghOhio', 'name': 'Conscientious Objector; WILPF lover; ERA Voter', 'id': 1196524402000703495, 'id_str': '1196524402000703495', 'indices': [0, 16]}, {'screen_name': 'dr_cmm', 'name': 'Dr. Cole - click on my notify icon 🔔', 'id': 946344888, 'id_str': '946344888', 'indices': [17, 24]}], 'urls': [{'url': 'https://t.co/G0Tk55oI3k', 'expanded_url': 'https://twitter.com/i/web/status/1447921822515793933', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1447913407743680514, 'in_reply_to_status_id_str': '1447913407743680514', 'in_reply_to_user_id': 1196524402000703495, 'in_reply_to_user_id_str': '1196524402000703495', 'in_reply_to_screen_name': 'StefMayoPghOhio', 'user': {'id': 1249838656166256641, 'id_str': '1249838656166256641', 'name': 'Darnell LMB', 'screen_name': 'Darnelouise', 'location': 'Michigan, USA', 'description': 'Christian,Family-Wife-Mother, #Retired RN-BSN,#MeToo , #WTP, #Vaxxed, #FBR, #GH,#drcole, #BlackLivesMatter, #BidenHarris,#BeKind,NO MAGAt, No$, No DM', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4568, 'friends_count': 5018, 'listed_count': 7, 'created_at': 'Mon Apr 13 23:16:20 +0000 2020', 'favourites_count': 13393, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 15742, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1439644788119244803/MZiBDLlY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1439644788119244803/MZiBDLlY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1249838656166256641/1632107439', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 12, 13, 47, 18, tzinfo=datetime.timezone.utc), id=1447921822515793933, id_str='1447921822515793933', text='@StefMayoPghOhio @dr_cmm So sorry to hear #Covid hits people differently. Long term Covid problems are devastating… https://t.co/G0Tk55oI3k', truncated=True, entities={'hashtags': [{'text': 'Covid', 'indices': [42, 48]}], 'symbols': [], 'user_mentions': [{'screen_name': 'StefMayoPghOhio', 'name': 'Conscientious Objector; WILPF lover; ERA Voter', 'id': 1196524402000703495, 'id_str': '1196524402000703495', 'indices': [0, 16]}, {'screen_name': 'dr_cmm', 'name': 'Dr. Cole - click on my notify icon 🔔', 'id': 946344888, 'id_str': '946344888', 'indices': [17, 24]}], 'urls': [{'url': 'https://t.co/G0Tk55oI3k', 'expanded_url': 'https://twitter.com/i/web/status/1447921822515793933', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, meta ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:46:56 +0000 2021', 'id': 1447921729825824783, 'id_str': '1447921729825824783', 'text': "RT @HJapanGalaxyII: Geneticist Alexandra Henrion-Caude: We don't know if the vaccinated can have children or not\nThe research by French gen…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'HJapanGalaxyII', 'name': '日本銀河系農場2', 'id': 1323919390446817280, 'id_str': '1323919390446817280', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1402837960483958793, 'id_str': '1402837960483958793', 'name': 'Alvin火龙果2', 'screen_name': 'AlvinPitaya', 'location': '', 'description': '喜马拉雅，勇往直前！GTV：火龙果/Getome：Pitaya———新号，旧号被封。', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 636, 'friends_count': 252, 'listed_count': 6, 'created_at': 'Thu Jun 10 04:01:44 +0000 2021', 'favourites_count': 39111, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 36578, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1411878824480960515/aSs2OJct_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1411878824480960515/aSs2OJct_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1402837960483958793/1633046347', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 05:42:00 +0000 2021', 'id': 1447799695338655746, 'id_str': '1447799695338655746', 'text': "Geneticist Alexandra Henrion-Caude: We don't know if the vaccinated can have children or not\nThe research by French… https://t.co/ksGaP1C8z5", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ksGaP1C8z5', 'expanded_url': 'https://twitter.com/i/web/status/1447799695338655746', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1323919390446817280, 'id_str': '1323919390446817280', 'name': '日本銀河系農場2', 'screen_name': 'HJapanGalaxyII', 'location': '', 'description': '原日本银河系农场推号被冻结。请follow信号', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 811, 'friends_count': 230, 'listed_count': 8, 'created_at': 'Wed Nov 04 09:26:06 +0000 2020', 'favourites_count': 7431, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8875, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_back ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:46:36 +0000 2021', 'id': 1447921645985878027, 'id_str': '1447921645985878027', 'text': 'RT @StefSimanowitz: 1/. #BREAKING #COVID NEWSFLASH: The “official scientific advisers" behind the #HerdImmunityScandal were in reality were…', 'truncated': False, 'entities': {'hashtags': [{'text': 'BREAKING', 'indices': [24, 33]}, {'text': 'COVID', 'indices': [34, 40]}, {'text': 'HerdImmunityScandal', 'indices': [98, 118]}], 'symbols': [], 'user_mentions': [{'screen_name': 'StefSimanowitz', 'name': 'Stefan Simanowitz', 'id': 115393565, 'id_str': '115393565', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 27426996, 'id_str': '27426996', 'name': 'alan seymour', 'screen_name': 'sportmarketing1', 'location': 'Cambridge, England', 'description': 'University Lecturer Consultant in Sports Marketing -Conference/Social Media @FOSConf MCIPR- Liverpool Supporter-Future of Sport Radio host #Remainer #Author ❤EU', 'url': 'https://t.co/gRc1S10zZp', 'entities': {'url': {'urls': [{'url': 'https://t.co/gRc1S10zZp', 'expanded_url': 'http://about.me/alanseymour', 'display_url': 'about.me/alanseymour', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 11859, 'friends_count': 13037, 'listed_count': 491, 'created_at': 'Sun Mar 29 13:57:02 +0000 2009', 'favourites_count': 108316, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 139372, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1302584449784328192/_1QIr4vz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1302584449784328192/_1QIr4vz_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27426996/1599395166', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 06:52:02 +0000 2021', 'id': 1447817316335595520, 'id_str': '1447817316335595520', 'text': '1/. #BREAKING #COVID NEWSFLASH: The “official scientific advisers" behind the #HerdImmunityScandal were in reality… https://t.co/E4oWM2IG8I', 'truncated': True, 'entities': {'hashtags': [{'text': 'BREAKING', 'indices': [4, 13]}, {'text': 'COVID', 'indices': [14, 20]}, {'text': 'HerdImmunityScandal', 'indices': [78, 98]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/E4oWM2IG8I', 'expanded_url': 'https://twitter.com/i/web/status/1447817316335595520', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 115393565, 'id_str': '115393565', 'name': 'Stefan Simanowitz', 'scre ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:43:53 +0000 2021', 'id': 1447920964357050385, 'id_str': '1447920964357050385', 'text': '@BBCNews @robertcuffe Worth remembering that anyone with even marginal cardiac or respiratory impairment post… https://t.co/cvUB4Ojq1K', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BBCNews', 'name': 'BBC News (UK)', 'id': 612473, 'id_str': '612473', 'indices': [0, 8]}, {'screen_name': 'robertcuffe', 'name': 'Robert Cuffe', 'id': 60854393, 'id_str': '60854393', 'indices': [9, 21]}], 'urls': [{'url': 'https://t.co/cvUB4Ojq1K', 'expanded_url': 'https://twitter.com/i/web/status/1447920964357050385', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [111, 134]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1447919799149989889, 'in_reply_to_status_id_str': '1447919799149989889', 'in_reply_to_user_id': 269864868, 'in_reply_to_user_id_str': '269864868', 'in_reply_to_screen_name': 'Bkasparas', 'user': {'id': 269864868, 'id_str': '269864868', 'name': 'Bernard Kasparas 💙', 'screen_name': 'Bkasparas', 'location': 'Surrey', 'description': 'Ex-Train Driver Instructor @GWRHelp ;still doing a bit of #cameraman stuff with an eye on events in #NonLeague #football & #Germany https://t.co/3x3tzUSXFP', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/3x3tzUSXFP', 'expanded_url': 'http://t.me/Bernard_Kaspara', 'display_url': 't.me/Bernard_Kaspara', 'indices': [132, 155]}]}}, 'protected': False, 'followers_count': 414, 'friends_count': 487, 'listed_count': 19, 'created_at': 'Mon Mar 21 15:53:44 +0000 2011', 'favourites_count': 7476, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 19158, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '9AE4E8', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1183773875995328512/zD05oLKE_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183773875995328512/zD05oLKE_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/269864868/1541901690', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'BDDCAD', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 12, 13, 43, 53, tzinfo=datetime.timezone.utc), id=1447920964357050385, id_str='1447920964357050385', text='@BBCNews @robertcuffe Worth remembering that anyone with even marginal cardiac or respiratory impairment post… https://t.co/cvUB4Ojq1K', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BBCNews', 'name': 'BBC News (UK)', 'id': 612473, 'id_str': '612473', 'indices': [0, 8]}, {'screen_name': 'robertcuffe', 'name': 'Robert Cuffe', 'id': 60854393, 'id_str': '60854393', 'indices': [9, 21]}], 'urls': [{'url': 'https://t.co/cvUB4Ojq1K', 'expanded_url': 'https://twitter.com/i/web/status/1447920964357050385', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [111, 134]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:43:43 +0000 2021', 'id': 1447920923668099086, 'id_str': '1447920923668099086', 'text': 'RT @DrEricDing: Progress or no? \n\n📌1918–The Great Pandemic. With no vaccines—50 million died.\n \n📌1969–Humans land on the moon\n\n📌2020–COVID…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DrEricDing', 'name': 'Eric Feigl-Ding', 'id': 18831926, 'id_str': '18831926', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 423764764, 'id_str': '423764764', 'name': 'Marcia Gascho', 'screen_name': 'magascho', 'location': 'indianapolis', 'description': 'I love Korean dramas, traveling on Route 66, writing articles for IndyKorea magazine, studying about Germany and volunteering for Indiana Landmarks.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 913, 'friends_count': 1865, 'listed_count': 2, 'created_at': 'Mon Nov 28 22:26:54 +0000 2011', 'favourites_count': 199188, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 98718, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1679773145/HPIM0181_rev_1__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1679773145/HPIM0181_rev_1__normal.jpg', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 07:20:15 +0000 2021', 'id': 1447824420983263236, 'id_str': '1447824420983263236', 'text': 'Progress or no? \n\n📌1918–The Great Pandemic. With no vaccines—50 million died.\n \n📌1969–Humans land on the moon\n\n📌202… https://t.co/LUJll9I4bz', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/LUJll9I4bz', 'expanded_url': 'https://twitter.com/i/web/status/1447824420983263236', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18831926, 'id_str': '18831926', 'name': 'Eric Feigl-Ding', 'screen_name': 'DrEricDing', 'location': 'Washington DC & Virginia', 'description': "Epidemiologist & health economist. Senior Fellow @FAScientists. Health policy @NECSI. Former 16 years @Harvard. @JohnsHopkins alum. COVID Updates since Jan '20", 'url': 'https://t.co/ipohSRjmIW', 'entities': {'url': {'urls': [{'url': 'https://t.co/ipohSRjmIW', 'expanded_url': 'http://fas.org/expert/eric-feigl-ding/', 'display_url': 'fas.org/expert/eric-fe…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 595167, 'friends_count': 9534, ' ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:43:42 +0000 2021', 'id': 1447920917217222660, 'id_str': '1447920917217222660', 'text': 'Reaching out in #Covid, we learned something. With trade shows and meetings cancelled or online, we adapted our… https://t.co/RYIyiIYeUQ', 'truncated': True, 'entities': {'hashtags': [{'text': 'Covid', 'indices': [16, 22]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/RYIyiIYeUQ', 'expanded_url': 'https://twitter.com/i/web/status/1447920917217222660', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 17396158, 'id_str': '17396158', 'name': 'Atlas Polar Company Ltd.', 'screen_name': 'atlaspolar', 'location': 'Toronto, Canada', 'description': 'Atlas Polar – Canada’s #1 truck-mounted equipment: HIAB, Moffett Multilift, new and pre-owned and work-ready packages, HiVOLT ALERT, waterways systems & more.', 'url': 'http://t.co/s8f4GEauR6', 'entities': {'url': {'urls': [{'url': 'http://t.co/s8f4GEauR6', 'expanded_url': 'http://www.atlaspolar.com', 'display_url': 'atlaspolar.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 75, 'friends_count': 164, 'listed_count': 2, 'created_at': 'Fri Nov 14 21:23:52 +0000 2008', 'favourites_count': 3, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 284, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '003C7B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1386759838072442886/6w5RTQMy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1386759838072442886/6w5RTQMy_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17396158/1620167803', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBEB', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 12, 13, 43, 42, tzinfo=datetime.timezone.utc), id=1447920917217222660, id_str='1447920917217222660', text='Reaching out in #Covid, we learned something. With trade shows and meetings cancelled or online, we adapted our… https://t.co/RYIyiIYeUQ', truncated=True, entities={'hashtags': [{'text': 'Covid', 'indices': [16, 22]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/RYIyiIYeUQ', 'expanded_url': 'https://twitter.com/i/web/status/1447920917217222660', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=None, _json={'id': 17396158, 'id_str': '17396158', 'name': 'Atlas Polar Company Ltd.', 'screen_name': 'atlaspolar', 'location': 'Toronto, Canad ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:42:28 +0000 2021', 'id': 1447920608021553160, 'id_str': '1447920608021553160', 'text': 'RT @StefSimanowitz: 1/. #BREAKING #COVID NEWSFLASH: The “official scientific advisers" behind the #HerdImmunityScandal were in reality were…', 'truncated': False, 'entities': {'hashtags': [{'text': 'BREAKING', 'indices': [24, 33]}, {'text': 'COVID', 'indices': [34, 40]}, {'text': 'HerdImmunityScandal', 'indices': [98, 118]}], 'symbols': [], 'user_mentions': [{'screen_name': 'StefSimanowitz', 'name': 'Stefan Simanowitz', 'id': 115393565, 'id_str': '115393565', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4340717595, 'id_str': '4340717595', 'name': 'Verónica Hinestroza', 'screen_name': 'Laveroha', 'location': '🌎  LatAm ', 'description': 'Senior Legal Advisor @FairTrials|Expert @Omega_RF & @J_RapidResponse|Advisory @oudhsv| #MendezPrinciples |@issnl #IAmChevening #WeAreEssex|⚖ 🐕|Español|My views', 'url': 'https://t.co/HLb5Fr011w', 'entities': {'url': {'urls': [{'url': 'https://t.co/HLb5Fr011w', 'expanded_url': 'https://www.atlaswomen.org/profiles/2020/11/17/veronica-hinestroza-arenas', 'display_url': 'atlaswomen.org/profiles/2020/…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1454, 'friends_count': 1802, 'listed_count': 15, 'created_at': 'Tue Dec 01 14:48:39 +0000 2015', 'favourites_count': 18059, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6857, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1426320721970597891/YnE4AVQ9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1426320721970597891/YnE4AVQ9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4340717595/1620614627', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Oct 12 06:52:02 +0000 2021', 'id': 1447817316335595520, 'id_str': '1447817316335595520', 'text': '1/. #BREAKING #COVID NEWSFLASH: The “official scientific advisers" behind the #HerdImmunityScandal were in reality… https://t.co/E4oWM2IG8I', 'truncated': True, 'entities': {'hashtags': [{'text': 'BREAKING', 'indices': [4, 13]}, {'text': 'COVID', 'indices': [14, 20]}, {'text': 'HerdImmunityScandal', 'indices': [78, 98]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/E4oWM2IG8I', 'expanded_url': 'https://twitter.com/i/web/status/1447817316335595520', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 115393565, 'id_str' ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:41:48 +0000 2021', 'id': 1447920438215053314, 'id_str': '1447920438215053314', 'text': 'DYK?\n🔸 NYS Paid Leave for COVID-19 Vax Law gives workers up to 4 hours of leave per #COVID-19 vaccine injection, fo… https://t.co/tuH1bRs9A3', 'truncated': True, 'entities': {'hashtags': [{'text': 'COVID', 'indices': [84, 90]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/tuH1bRs9A3', 'expanded_url': 'https://twitter.com/i/web/status/1447920438215053314', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 113468433, 'id_str': '113468433', 'name': 'NYC Consumer and Worker Protection', 'screen_name': 'NYCDCA', 'location': 'New York, NY', 'description': 'Department of Consumer and Worker Protection (DCWP)—formerly DCA—protects and enhances the daily economic lives of New Yorkers. Account is not monitored 24/7.', 'url': 'https://t.co/6QeT9SHPNa', 'entities': {'url': {'urls': [{'url': 'https://t.co/6QeT9SHPNa', 'expanded_url': 'http://nyc.gov/dcwp', 'display_url': 'nyc.gov/dcwp', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 16542, 'friends_count': 1213, 'listed_count': 357, 'created_at': 'Thu Feb 11 21:29:02 +0000 2010', 'favourites_count': 8837, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 13876, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1268B3', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1146435586498150401/43OZzyer_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1146435586498150401/43OZzyer_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/113468433/1624396620', 'profile_link_color': '1268B3', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1447910171783712774, 'quoted_status_id_str': '1447910171783712774', 'quoted_status': {'created_at': 'Tue Oct 12 13:01:00 +0000 2021', 'id': 1447910171783712774, 'id_str': '1447910171783712774', 'text': 'Once again, this year’s #FluSeason will occur during the #COVID19 pandemic. Get your #FluShot early. You can also g… https://t.co/7DoM0ZLuCJ', 'truncated': True, 'entities': {'hashtags': [{'text': 'FluSeason', 'indices': [24, 34]}, {'text': 'COVID19', 'indices': [57, 65]}, {'text': 'FluShot', 'indices': [85, 93]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/7DoM0ZLuCJ', 'expanded_url': 'https://twitter.com/i/web/status/1447910171783712774', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2962245395, 'id_str': '2962245395', 'name':  ...
#  Status(_api=None, _json={'created_at': 'Tue Oct 12 13:41:10 +0000 2021', 'id': 1447920278168866829, 'id_str': '1447920278168866829', 'text': 'RT @Poximity: Still Life - Day 651 (give or take) since bat bit man / lady ate pangolin / virus snuck out of weapons lab / whatever happene…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Poximity', 'name': 'Poximity', 'id': 2866996599, 'id_str': '2866996599', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 74269720, 'id_str': '74269720', 'name': 'BobbyBitch', 'screen_name': 'LoveAlwaysShani', 'location': 'At yo daddy house ', 'description': 'Complicated Beauty !!!! Esthetician Pisces ♊️ 🇩🇴 IG: Therealshani.b', 'url': 'https://t.co/YlrHeKfLTu', 'entities': {'url': {'urls': [{'url': 'https://t.co/YlrHeKfLTu', 'expanded_url': 'https://onlyfans.com/pinkbesos', 'display_url': 'onlyfans.com/pinkbesos', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1499, 'friends_count': 1280, 'listed_count': 1, 'created_at': 'Mon Sep 14 21:28:12 +0000 2009', 'favourites_count': 1107, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 20406, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '642D8B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1386386650721357825/oaDH79Zs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1386386650721357825/oaDH79Zs_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74269720/1541952847', 'profile_link_color': 'FF0000', 'profile_sidebar_border_color': '65B0DA', 'profile_sidebar_fill_color': '7AC3EE', 'profile_text_color': '3D1957', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 06 23:37:59 +0000 2021', 'id': 1445896148128964610, 'id_str': '1445896148128964610', 'text': 'Still Life - Day 651 (give or take) since bat bit man / lady ate pangolin / virus snuck out of weapons lab / whatev… https://t.co/rCr0L5hH5y', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/rCr0L5hH5y', 'expanded_url': 'https://twitter.com/i/web/status/1445896148128964610', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2866996599, 'id_str': '2866996599', 'name': 'Poximity', 'screen_name': 'Poximity', 'location': '', 'description': 'Diamonds & debris from the rich tapestry of life... Insta: https://t.co/Jh6kyNVs9m', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/Jh6kyNVs9m', 'expanded_url': 'https://www.instagram.com/poximity/', 'display_url': 'instagram.com/poximity/', 'indices': [59, 82]}]}}, 'protected': False, 'followers_count': 9 ...

# %%
# We can see the text from the first tweet:

print(covid_tweets[0][0].text) # covid_tweets[0][0] is the first Status (tweet) object
# Out:
# RT @wqbelle: To mask, or not to mask, that should not be a question.
#
# https://t.co/Sa4xEjK9wp
#
# I have to shake my head at all the protests…

# %% [markdown]
# Twitter data is nested.
#
# This means that it can contain items within items.
#
# For example hashtags, user mentions, and URLs are contained within an `entities` dictionary.
#
# This looks like:
#
# ```
# 'entities': {
#     'hashtags': [{'hashtag1'}, {'hashtag2'}],
#     'user_mentions': [{'screen_name':'barackobama', 'name': 'Barack Obama'}],
#     'urls': [{'url':'www.bbc.co.uk'}]
#     }
# ```

# %%
# The hashtags are contained in a list within the entity tuple,
# which means we need to call the entity tuple (hashtag) and then iterate through the list.
# We set up a list to hold the hashtags so we can then append to it as we iterate.
# We iterate through each tweet, and then through the hashtags in the list,
# adding the tweets to the list.

covid_hashtags = []
for search_result in covid_tweets:
    for status in search_result:  # for every tweet
        hashtags = status.entities['hashtags']
        if len(hashtags) > 0:     # if there are hashtags
            for h in hashtags:
                covid_hashtags.append(h['text'])

print(covid_hashtags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-700137aa1ce8> in <module>
#       6
#       7 covid_hashtags = []
# ----> 8 for search_result in covid_tweets:
#       9     for status in search_result:  # for every tweet
#      10         hashtags = status.entities['hashtags']
#
# NameError: name 'covid_tweets' is not defined

# %%
# We can then visualise these hashtags in the ways we learnt before.

hashtag_string = " ".join(covid_hashtags)
tokens = word_tokenize(hashtag_string)
simple_frequencies_dict_covid = Counter(tokens)
cloud = WordCloud(width=800, height=400, max_font_size=160, 
                  colormap="viridis", 
                  background_color='white',).generate_from_frequencies(simple_frequencies_dict_covid)
plt.figure(figsize=(16,12))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🐛Minitask
#
# * Try creating a visualisation with a different nested item.

# %%
# # Have this as a task -- look for another item of interest, maybe alter to be URLs?

# covid_mentions = []
# for search_result in covid_tweets:
#     for status in search_result:
#         mention = status._json['entities']['user_mentions']
#         if len(mention) > 0:
#             i = 0
#             while i < len(mention):
#                 covid_mentions.append(mention[i]['name'])
#                 i += 1
# people_dict=Counter(covid_mentions)

# %%
# cloud = WordCloud(width=800, height=400, max_font_size=200,
#                   background_color='white', colormap="viridis").generate_from_frequencies(people_dict)
# plt.figure(figsize=(16,12))
# plt.imshow(cloud, interpolation='bilinear')
# plt.axis('off')
# plt.show()

# %%
# covid_tweets = []
# for page in tweepy.Cursor(api.search, q='brexit', lang='en', min_retweets="1000").pages(100):
#     covid_tweets.append(page)

# %%
# print(len(covid_tweets))
# print(covid_tweets[0])
